# %%
import numpy as np
import pandas as pd
import pickle
import pickle as pk

import os,sys
import pylab as plt
import torch
import shutil, os, csv, itertools, glob

import math
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
import math
# model
cuda = torch.cuda.is_available()
class MLP(nn.Module):
    def __init__(self,in_dim, output_dim,hidden_dim=96):
        super(MLP,self).__init__()
        self.fc1 = nn.Linear(in_dim,hidden_dim)
#         self.fc2 = nn.Linear(hidden_dim*2,hidden_dim)
        self.fc3 = nn.Linear(hidden_dim,output_dim)
        
    def forward(self,din):
#         din = din.view(-1,28*28)
        dout = F.tanh(self.fc1(din))
#         dout = F.relu(self.fc2(dout))
        return self.fc3(dout)

def load_pickle(filename):
    try:
        p = open(filename, 'rb')
    except IOError:
        print("Pickle file cannot be opened.")
        return None
    try:
        picklelicious = pk.load(p)
    except ValueError:
        print('load_pickle failed once, trying again')
        p.close()
        p = open(filename, 'rb')
        picklelicious = pk.load(p)

    p.close()
    return picklelicious
def save_pickle(data_object, filename):
    pickle_file = open(filename, 'wb')
    pk.dump(data_object, pickle_file)
    pickle_file.close()
def path_exist(path):
    if not os.path.exists(path):
        os.mkdir(path)
def get_best_checkpoint(model_path):
    return model_path+'/model_best.pth.tar'
def save_checkpoint(state, is_best, filename):
    model_path,_=os.path.split(filename)
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, model_path+'/model_best.pth.tar')
def destroy_checkpoint(model_path):
    fs = sorted([f for f in os.listdir(model_path) if 'Epoch' in f], key=lambda k: int(k.split()[1]))
#     for f in os.listdir(model_path):
#         if 'Epoch' in f and f != fs:
#             os.remove(f) 
    try:
        for f in os.listdir(model_path):
            if 'Epoch' in f and str(f) != str(fs[-1]):
                os.remove(model_path+f)
        return True
    except:
        return False

# %%
class Load_Dataset(Dataset):
    # Initialize your data, download, etc.
    def __init__(self, dataset):
        super(Load_Dataset, self).__init__()

        X_train = dataset["samples"]
        y_train = dataset["labels"]

        if len(X_train.shape) < 3:
            X_train = X_train.unsqueeze(2)

        if X_train.shape.index(min(X_train.shape)) != 1:  # make sure the Channels in second dim
            X_train = X_train.permute(0, 2, 1)

        if isinstance(X_train, np.ndarray):
            self.x_data = torch.from_numpy(X_train)
            self.y_data = torch.from_numpy(y_train).long()
        else:
            self.x_data = X_train
            self.y_data = y_train

        self.len = X_train.shape[0]

    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index], self.x_data[index], self.x_data[index]

    def __len__(self):
        return self.len


def data_generator(data_path,batch_size=128):

    train_dataset = torch.load(os.path.join(data_path, "train.pt"))
    valid_dataset = torch.load(os.path.join(data_path, "val.pt"))
    test_dataset = torch.load(os.path.join(data_path, "test.pt"))

    train_dataset = Load_Dataset(train_dataset)
    valid_dataset = Load_Dataset(valid_dataset)
    test_dataset = Load_Dataset(test_dataset)
    

    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size,
                                               shuffle=True, drop_last=False,
                                               num_workers=0)
    valid_loader = torch.utils.data.DataLoader(dataset=valid_dataset, batch_size=batch_size,
                                               shuffle=False, drop_last=False,
                                               num_workers=0)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size,
                                              shuffle=False, drop_last=False,
                                              num_workers=0)

    return train_loader, valid_loader, test_loader

# %%
HAR_path=f"./HAR"
epilepsy_path=f"./Epilepsy"

# %%
train_loader, valid_loader, test_loader=data_generator(HAR_path,128)

# %%
class my_encoder(nn.Module):
    def __init__(self,
                 sizeHidden=512,
                 normMode="layerNorm"):

        super(my_encoder, self).__init__()

        validModes = ["batchNorm", "instanceNorm", "ID", "layerNorm"]
        if normMode not in validModes:
            raise ValueError(f"Norm mode must be in {validModes}")

        if normMode == "instanceNorm":
            def normLayer(x): return nn.InstanceNorm1d(x, affine=True)
        elif normMode == "ID":
            normLayer = cpc_model.IDModule
        elif normMode == "layerNorm":
            normLayer = cpc_model.ChannelNorm
        else:
            normLayer = nn.BatchNorm1d

        self.dimEncoded = sizeHidden
        self.conv0 = nn.Conv1d(9, sizeHidden, 8, dilation=1, stride=2, padding=4)
        self.batchNorm0 = normLayer(sizeHidden)
        self.conv1 = nn.Conv1d(sizeHidden, sizeHidden, 4, dilation=1, stride=2, padding=2)
        self.batchNorm1 = normLayer(sizeHidden)
        self.conv2 = nn.Conv1d(sizeHidden, sizeHidden, 4, dilation=1, stride=2, padding=2)
        self.batchNorm2 = normLayer(sizeHidden)
        self.DOWNSAMPLING = 160

    def getDimOutput(self):
        return self.conv3.out_channels

    def forward(self, x):
        x = F.relu(self.batchNorm0(self.conv0(x)))
        x = F.relu(self.batchNorm1(self.conv1(x)))
        x = F.relu(self.batchNorm2(self.conv2(x)))
        return x
import argparse
import cpc.criterion as cr
import cpc.model as cpc_model
import cpc.feature_loader as fl
prompt_seq=4
class union_model(torch.nn.Module):
    def __init__(self):
        super(union_model, self).__init__()
        #cpc for smoothness
        args = argparse.ArgumentParser().parse_args(args=[])
        hidden=64
        args.hiddenEncoder=hidden
        args.outputdim=hidden
        args.hiddenGar=hidden
        args.arMode='transformer'
        args.samplingType= None #'sequential'
        args.cpc_mode="sequential" #'reverse'
        args.nLevelsGRU=3
        args.sizeWindow=160 * (17+prompt_seq) #for transformer
        args.abspos=True
        args.negativeSamplingExt=32  #model setting
        cpc_encoder=my_encoder(args.hiddenEncoder,"batchNorm")
        cpc_ar=fl.getAR(args)
        self.cpc_model=cpc_model.CPCModel_Promote_multi_seq_t(cpc_encoder,cpc_ar,hidden_dim=hidden,prompt_seq=prompt_seq)
        self.cpc_criterion=cr.CPCUnsupersivedCriterion(8,   # Number of steps
                         args.hiddenGar,           # Dimension of G_ar
                         args.outputdim,      # Dimension of the convolutional net
                         args.negativeSamplingExt,   # Number of negative samples to draw
                         mode=None,
                         rnnMode='lstm',
                         dropout=False,
                         speakerEmbedding=0,
                         nSpeakers=0,
                         sizeInputSeq=20) #for transformer
        for param in self.cpc_model.parameters():
            param.requires_grad = True
        self.cpc_model.eval()
        self.cpc_criterion.eval()
    def forward(self,x,label):
        representation,c_feature, encoded_data, label = self.cpc_model(x,label)
        cpc_loss,cpc_ac= self.cpc_criterion(c_feature, encoded_data, label)
        cpc_loss=cpc_loss.sum()
        cpc_ac=cpc_ac.mean()
        return representation,c_feature,encoded_data,cpc_loss,cpc_ac

# %%
def train(epoch,model,train_data_loader,optimizer,scheduler,criterion=nn.MSELoss()):
    model.train()
    train_loss = 0.
    accuracy=[]
    print_time=int(len(train_data_loader)/3)+1
    for batch_idx, (data, target,_,_) in enumerate(train_data_loader):
        data = data.float()
        if cuda:
            data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        representation,c_feature,encoded_data,loss,cpc_ac = model(data,target)
        train_loss+=loss.data.item()
        accuracy.append(cpc_ac.item())
        loss.backward()
        optimizer.step()
        scheduler.step()
        if batch_idx % print_time == 0:
            print('\r Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} Acc: {:.2f}%/{:.2f}%'.format(
                epoch, batch_idx, len(train_data_loader),
                100. * batch_idx / len(train_data_loader), loss.data.item(),
                100. *cpc_ac.item(),100. * np.mean(accuracy)))
    train_loss=train_loss/len(train_data_loader)
    print('Train set: Average loss: {:.4f} Acc:{:.2f}%'.format(
        train_loss, 100.* np.mean(accuracy)))
    return train_loss,np.mean(accuracy)
def test(model,valid_data_loader,criterion=nn.MSELoss()):
    model.eval()
    test_loss = 0.
    preds = []
    ar_preds = []
    r_preds = []
    accuracy=[]
    for (data, target,_,_) in valid_data_loader:
        data = data.float()
        if cuda:
            data, target = data.cuda(), target.cuda()
        representation,c_feature,encoded_data,loss,cpc_ac = model(data,target)
        test_loss += loss.data.item() # sum up batch loss
        preds.append(encoded_data.detach().cpu().numpy())
        ar_preds.append(c_feature.detach().cpu().numpy())
        r_preds.append(representation.detach().cpu().numpy())
        accuracy.append(cpc_ac.item())
    test_loss=test_loss/len(valid_data_loader)
    print('Test set: Average loss: {:.4f}, Accuracy:({:.2f}%)'.format(
        test_loss, 100. * np.mean(accuracy)))
#     return np.concatenate(preds,axis=0), test_loss,np.mean(accuracy)
    return preds,ar_preds,r_preds, test_loss,np.mean(accuracy)

def experiment(num_epoch=5,lr=0.001,resume=True):
    global train_loader,test_loader,model_path,model
    
    start_epoch = 0
    best_res = 1e9
    losscurve = []
    accurve = []
                  
    resume_state = get_best_checkpoint(model_path) if resume else None
    if resume_state and os.path.isfile(resume_state):
        print("=> loading checkpoint '{}'".format(resume_state))
        checkpoint = torch.load(resume_state,map_location={'cuda:0':'cuda:8'})
        start_epoch = checkpoint['epoch']+1
        best_res = checkpoint['best_res']
        losscurve = checkpoint['losscurve']
        accurve = checkpoint['accurve']
        model.load_state_dict(checkpoint['state_dict'])
        if cuda:
            model.cuda()
        optimizer = optim.Adam(model.parameters(),lr=lr, weight_decay=0.0005)
        optimizer.load_state_dict(checkpoint['optimizer'])
        scheduler = checkpoint['scheduler']
        print("=> loaded checkpoint '{}' (epoch {})"
              .format(resume_state, checkpoint['epoch']))
    else:
        if cuda:
            model.cuda()
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=0.0005)
        scheduler = lr_scheduler.CyclicLR(optimizer, lr / 10, lr*2, step_size_up=10, step_size_down=10,
                                       cycle_momentum=False, mode="triangular")
    
    
    for epoch in range(start_epoch,start_epoch+num_epoch):
        is_best = False
        train_loss,train_ac = train(epoch,model,train_loader,optimizer,scheduler)
        _,_,_, val_loss,val_ac = test(model,valid_loader)
        losscurve.append((train_loss, val_loss))
        accurve.append((train_ac,val_ac))
        if val_loss < best_res:
            best_res = val_loss
            is_best = True
            save_checkpoint({
                    'epoch': epoch,
        #                 'arch': model.arch,
                    'state_dict': model.cpu().state_dict(),
                    'train_loss':train_loss,
                    'val_loss': val_loss,
                    'best_res':best_res,
                    'optimizer' : optimizer.state_dict(),
                    'scheduler' : scheduler,
                    'losscurve':losscurve,
                    'accurve':accurve,
                }, is_best,
                model_path+"Epoch %d Acc %.4f.pt"%(epoch, val_loss))
        if cuda:
            model.cuda()
    return losscurve,accurve

# %%
model_path="./model/cpc_open_har_mp/"
torch.cuda.set_device(1)
model = union_model()

# %%
path_exist(model_path)
losscurve,accurve=experiment(50,resume=True)
plt.plot([i[0] for i in losscurve],label="train loss")
plt.plot([i[1] for i in losscurve],label="validation loss")
plt.legend()
plt.show()
plt.plot([i[0] for i in accurve],label="train ac")
plt.plot([i[1] for i in accurve],label="validation ac")
plt.legend()
plt.show()
# Out:
#  Train Epoch: 0 [0/46 (0%)]	Loss: 27.977200 Acc: 3.37%/3.37%
#  Train Epoch: 0 [16/46 (35%)]	Loss: 24.720982 Acc: 11.20%/9.18%
#  Train Epoch: 0 [32/46 (70%)]	Loss: 22.109146 Acc: 11.64%/10.08%
# Train set: Average loss: 24.1606 Acc:10.45%
# Test set: Average loss: 21.4296, Accuracy:(11.13%)
#  Train Epoch: 1 [0/46 (0%)]	Loss: 21.315693 Acc: 9.74%/9.74%
#  Train Epoch: 1 [16/46 (35%)]	Loss: 19.791126 Acc: 13.72%/11.46%
#  Train Epoch: 1 [32/46 (70%)]	Loss: 18.991367 Acc: 14.46%/12.54%
# Train set: Average loss: 19.7411 Acc:13.30%
# Test set: Average loss: 18.7649, Accuracy:(16.75%)
#  Train Epoch: 2 [0/46 (0%)]	Loss: 18.815922 Acc: 18.32%/18.32%
#  Train Epoch: 2 [16/46 (35%)]	Loss: 18.486568 Acc: 15.44%/16.69%
#  Train Epoch: 2 [32/46 (70%)]	Loss: 17.958759 Acc: 16.76%/16.74%
# Train set: Average loss: 18.2532 Acc:17.53%
# Test set: Average loss: 17.7987, Accuracy:(19.24%)
#  Train Epoch: 3 [0/46 (0%)]	Loss: 17.806292 Acc: 17.93%/17.93%
#  Train Epoch: 3 [16/46 (35%)]	Loss: 17.513210 Acc: 23.22%/20.76%
#  Train Epoch: 3 [32/46 (70%)]	Loss: 16.556568 Acc: 28.88%/22.95%
# Train set: Average loss: 16.9609 Acc:24.46%
# Test set: Average loss: 16.0253, Accuracy:(29.70%)
#  Train Epoch: 4 [0/46 (0%)]	Loss: 15.747939 Acc: 28.18%/28.18%
#  Train Epoch: 4 [16/46 (35%)]	Loss: 15.088561 Acc: 32.05%/31.09%
#  Train Epoch: 4 [32/46 (70%)]	Loss: 14.225768 Acc: 36.35%/31.86%
# Train set: Average loss: 14.8451 Acc:33.03%
# Test set: Average loss: 14.0607, Accuracy:(34.91%)
#  Train Epoch: 5 [0/46 (0%)]	Loss: 13.619099 Acc: 37.85%/37.85%
#  Train Epoch: 5 [16/46 (35%)]	Loss: 13.681422 Acc: 37.13%/39.23%
#  Train Epoch: 5 [32/46 (70%)]	Loss: 12.819996 Acc: 40.03%/39.00%
# Train set: Average loss: 12.9826 Acc:40.30%
# Test set: Average loss: 12.3020, Accuracy:(40.81%)
#  Train Epoch: 6 [0/46 (0%)]	Loss: 11.622469 Acc: 46.82%/46.82%
#  Train Epoch: 6 [16/46 (35%)]	Loss: 11.773869 Acc: 42.57%/44.88%
#  Train Epoch: 6 [32/46 (70%)]	Loss: 10.970579 Acc: 50.04%/47.40%
# Train set: Average loss: 11.2602 Acc:48.95%
# Test set: Average loss: 10.5517, Accuracy:(54.77%)
#  Train Epoch: 7 [0/46 (0%)]	Loss: 9.952799 Acc: 57.96%/57.96%
#  Train Epoch: 7 [16/46 (35%)]	Loss: 9.898783 Acc: 59.58%/56.41%
#  Train Epoch: 7 [32/46 (70%)]	Loss: 9.632917 Acc: 58.68%/57.64%
# Train set: Average loss: 9.6435 Acc:58.48%
# Test set: Average loss: 9.1350, Accuracy:(61.04%)
#  Train Epoch: 8 [0/46 (0%)]	Loss: 8.908486 Acc: 64.03%/64.03%
#  Train Epoch: 8 [16/46 (35%)]	Loss: 9.084444 Acc: 61.43%/63.45%
#  Train Epoch: 8 [32/46 (70%)]	Loss: 8.012155 Acc: 66.82%/63.83%
# Train set: Average loss: 8.3638 Acc:64.79%
# Test set: Average loss: 7.7766, Accuracy:(69.41%)
#  Train Epoch: 9 [0/46 (0%)]	Loss: 7.695642 Acc: 67.55%/67.55%
#  Train Epoch: 9 [16/46 (35%)]	Loss: 7.311668 Acc: 70.81%/69.74%
#  Train Epoch: 9 [32/46 (70%)]	Loss: 6.994011 Acc: 71.17%/70.13%
# Train set: Average loss: 7.2394 Acc:70.39%
# Test set: Average loss: 6.7784, Accuracy:(72.99%)
#  Train Epoch: 10 [0/46 (0%)]	Loss: 7.058332 Acc: 68.17%/68.17%
#  Train Epoch: 10 [16/46 (35%)]	Loss: 6.220068 Acc: 75.27%/72.33%
#  Train Epoch: 10 [32/46 (70%)]	Loss: 6.272003 Acc: 73.05%/72.67%
# Train set: Average loss: 6.4327 Acc:73.43%
# Test set: Average loss: 6.0649, Accuracy:(74.47%)
#  Train Epoch: 11 [0/46 (0%)]	Loss: 6.187233 Acc: 75.14%/75.14%
#  Train Epoch: 11 [16/46 (35%)]	Loss: 5.455808 Acc: 76.83%/74.12%
#  Train Epoch: 11 [32/46 (70%)]	Loss: 6.038603 Acc: 75.49%/74.69%
# Train set: Average loss: 5.8218 Acc:75.44%
# Test set: Average loss: 5.7197, Accuracy:(76.52%)
#  Train Epoch: 12 [0/46 (0%)]	Loss: 5.861065 Acc: 73.43%/73.43%
#  Train Epoch: 12 [16/46 (35%)]	Loss: 5.632342 Acc: 75.40%/76.54%
#  Train Epoch: 12 [32/46 (70%)]	Loss: 5.040031 Acc: 80.41%/77.03%
# Train set: Average loss: 5.3615 Acc:77.55%
# Test set: Average loss: 5.0662, Accuracy:(79.08%)
#  Train Epoch: 13 [0/46 (0%)]	Loss: 4.842206 Acc: 81.43%/81.43%
#  Train Epoch: 13 [16/46 (35%)]	Loss: 5.182217 Acc: 75.65%/77.74%
#  Train Epoch: 13 [32/46 (70%)]	Loss: 5.178469 Acc: 76.78%/78.25%
# Train set: Average loss: 4.9772 Acc:78.44%
# Test set: Average loss: 4.6307, Accuracy:(80.51%)
#  Train Epoch: 14 [0/46 (0%)]	Loss: 4.940595 Acc: 79.99%/79.99%
#  Train Epoch: 14 [16/46 (35%)]	Loss: 4.787632 Acc: 79.09%/79.43%
#  Train Epoch: 14 [32/46 (70%)]	Loss: 4.326115 Acc: 80.60%/80.06%
# Train set: Average loss: 4.5669 Acc:80.42%
# Test set: Average loss: 4.4268, Accuracy:(80.83%)
#  Train Epoch: 15 [0/46 (0%)]	Loss: 4.394026 Acc: 81.14%/81.14%
#  Train Epoch: 15 [16/46 (35%)]	Loss: 4.462800 Acc: 79.56%/81.66%
#  Train Epoch: 15 [32/46 (70%)]	Loss: 4.053827 Acc: 84.40%/81.61%
# Train set: Average loss: 4.2326 Acc:81.72%
# Test set: Average loss: 4.0526, Accuracy:(83.36%)
#  Train Epoch: 16 [0/46 (0%)]	Loss: 4.054467 Acc: 82.42%/82.42%
#  Train Epoch: 16 [16/46 (35%)]	Loss: 3.845549 Acc: 82.31%/82.96%
#  Train Epoch: 16 [32/46 (70%)]	Loss: 3.852529 Acc: 82.77%/82.85%
# Train set: Average loss: 3.9174 Acc:82.90%
# Test set: Average loss: 3.8140, Accuracy:(83.74%)
#  Train Epoch: 17 [0/46 (0%)]	Loss: 3.524973 Acc: 85.45%/85.45%
#  Train Epoch: 17 [16/46 (35%)]	Loss: 3.573130 Acc: 84.28%/84.19%
#  Train Epoch: 17 [32/46 (70%)]	Loss: 3.507213 Acc: 84.91%/84.14%
# Train set: Average loss: 3.5892 Acc:84.21%
# Test set: Average loss: 3.5405, Accuracy:(84.55%)
#  Train Epoch: 18 [0/46 (0%)]	Loss: 3.840014 Acc: 82.79%/82.79%
#  Train Epoch: 18 [16/46 (35%)]	Loss: 3.328192 Acc: 86.39%/84.58%
#  Train Epoch: 18 [32/46 (70%)]	Loss: 3.460487 Acc: 84.55%/84.33%
# Train set: Average loss: 3.4491 Acc:84.51%
# Test set: Average loss: 3.4444, Accuracy:(84.72%)
#  Train Epoch: 19 [0/46 (0%)]	Loss: 3.625545 Acc: 83.03%/83.03%
#  Train Epoch: 19 [16/46 (35%)]	Loss: 3.201725 Acc: 86.83%/84.66%
#  Train Epoch: 19 [32/46 (70%)]	Loss: 3.148849 Acc: 85.38%/84.66%
# Train set: Average loss: 3.3142 Acc:84.72%
# Test set: Average loss: 3.2015, Accuracy:(85.45%)
#  Train Epoch: 20 [0/46 (0%)]	Loss: 3.456609 Acc: 83.87%/83.87%
#  Train Epoch: 20 [16/46 (35%)]	Loss: 3.351694 Acc: 83.40%/84.66%
#  Train Epoch: 20 [32/46 (70%)]	Loss: 3.398514 Acc: 83.73%/84.57%
# Train set: Average loss: 3.2183 Acc:84.82%
# Test set: Average loss: 3.1409, Accuracy:(86.10%)
#  Train Epoch: 21 [0/46 (0%)]	Loss: 3.022374 Acc: 86.23%/86.23%
#  Train Epoch: 21 [16/46 (35%)]	Loss: 3.047682 Acc: 85.85%/85.11%
#  Train Epoch: 21 [32/46 (70%)]	Loss: 3.163728 Acc: 84.44%/85.12%
# Train set: Average loss: 3.1454 Acc:85.11%
# Test set: Average loss: 3.2113, Accuracy:(84.65%)
#  Train Epoch: 22 [0/46 (0%)]	Loss: 3.342186 Acc: 84.30%/84.30%
#  Train Epoch: 22 [16/46 (35%)]	Loss: 3.044915 Acc: 86.62%/85.86%
#  Train Epoch: 22 [32/46 (70%)]	Loss: 3.107444 Acc: 85.26%/85.62%
# Train set: Average loss: 2.9865 Acc:85.67%
# Test set: Average loss: 2.9975, Accuracy:(85.41%)
#  Train Epoch: 23 [0/46 (0%)]	Loss: 2.758070 Acc: 87.68%/87.68%
#  Train Epoch: 23 [16/46 (35%)]	Loss: 3.139616 Acc: 85.68%/85.71%
#  Train Epoch: 23 [32/46 (70%)]	Loss: 3.447786 Acc: 83.08%/85.79%
# Train set: Average loss: 2.9177 Acc:85.95%
# Test set: Average loss: 2.8938, Accuracy:(86.21%)
#  Train Epoch: 24 [0/46 (0%)]	Loss: 2.841574 Acc: 86.89%/86.89%
#  Train Epoch: 24 [16/46 (35%)]	Loss: 2.845134 Acc: 86.48%/85.98%
#  Train Epoch: 24 [32/46 (70%)]	Loss: 3.087353 Acc: 85.30%/85.82%
# Train set: Average loss: 2.8874 Acc:85.95%
# Test set: Average loss: 2.8638, Accuracy:(85.81%)
#  Train Epoch: 25 [0/46 (0%)]	Loss: 2.721223 Acc: 86.84%/86.84%
#  Train Epoch: 25 [16/46 (35%)]	Loss: 2.614376 Acc: 87.80%/86.49%
#  Train Epoch: 25 [32/46 (70%)]	Loss: 2.864463 Acc: 86.89%/86.33%
# Train set: Average loss: 2.7808 Acc:86.42%
# Test set: Average loss: 2.8036, Accuracy:(86.71%)
#  Train Epoch: 26 [0/46 (0%)]	Loss: 2.862002 Acc: 86.40%/86.40%
#  Train Epoch: 26 [16/46 (35%)]	Loss: 2.807515 Acc: 84.96%/86.53%
#  Train Epoch: 26 [32/46 (70%)]	Loss: 2.684786 Acc: 85.44%/86.32%
# Train set: Average loss: 2.7816 Acc:86.04%
# Test set: Average loss: 2.8534, Accuracy:(86.04%)
#  Train Epoch: 27 [0/46 (0%)]	Loss: 2.978204 Acc: 84.46%/84.46%
#  Train Epoch: 27 [16/46 (35%)]	Loss: 2.444201 Acc: 87.30%/86.69%
#  Train Epoch: 27 [32/46 (70%)]	Loss: 2.576265 Acc: 86.77%/86.67%
# Train set: Average loss: 2.7064 Acc:86.46%
# Test set: Average loss: 2.8305, Accuracy:(85.92%)
#  Train Epoch: 28 [0/46 (0%)]	Loss: 2.748024 Acc: 85.82%/85.82%
#  Train Epoch: 28 [16/46 (35%)]	Loss: 2.393236 Acc: 87.80%/86.76%
#  Train Epoch: 28 [32/46 (70%)]	Loss: 2.412285 Acc: 88.17%/86.50%
# Train set: Average loss: 2.6836 Acc:86.56%
# Test set: Average loss: 2.8397, Accuracy:(85.55%)
#  Train Epoch: 29 [0/46 (0%)]	Loss: 3.059834 Acc: 82.92%/82.92%
#  Train Epoch: 29 [16/46 (35%)]	Loss: 2.598910 Acc: 86.69%/86.37%
#  Train Epoch: 29 [32/46 (70%)]	Loss: 2.768258 Acc: 85.53%/86.49%
# Train set: Average loss: 2.6809 Acc:86.34%
# Test set: Average loss: 2.6958, Accuracy:(86.61%)
#  Train Epoch: 30 [0/46 (0%)]	Loss: 2.502186 Acc: 86.18%/86.18%
#  Train Epoch: 30 [16/46 (35%)]	Loss: 2.812619 Acc: 85.95%/86.96%
#  Train Epoch: 30 [32/46 (70%)]	Loss: 2.688266 Acc: 85.99%/86.85%
# Train set: Average loss: 2.6127 Acc:86.78%
# Test set: Average loss: 2.5972, Accuracy:(86.86%)
#  Train Epoch: 31 [0/46 (0%)]	Loss: 2.821108 Acc: 85.62%/85.62%
#  Train Epoch: 31 [16/46 (35%)]	Loss: 2.279823 Acc: 88.43%/86.51%
#  Train Epoch: 31 [32/46 (70%)]	Loss: 2.848910 Acc: 84.65%/86.86%
# Train set: Average loss: 2.5581 Acc:86.97%
# Test set: Average loss: 2.6219, Accuracy:(86.97%)
#  Train Epoch: 32 [0/46 (0%)]	Loss: 2.389350 Acc: 88.35%/88.35%
#  Train Epoch: 32 [16/46 (35%)]	Loss: 2.406798 Acc: 87.47%/87.61%
#  Train Epoch: 32 [32/46 (70%)]	Loss: 2.672034 Acc: 86.24%/87.48%
# Train set: Average loss: 2.4477 Acc:87.53%
# Test set: Average loss: 2.5818, Accuracy:(86.76%)
#  Train Epoch: 33 [0/46 (0%)]	Loss: 2.383658 Acc: 89.01%/89.01%
#  Train Epoch: 33 [16/46 (35%)]	Loss: 2.650502 Acc: 86.50%/86.94%
#  Train Epoch: 33 [32/46 (70%)]	Loss: 2.518396 Acc: 86.90%/86.98%
# Train set: Average loss: 2.5375 Acc:86.84%
# Test set: Average loss: 2.5414, Accuracy:(87.18%)
#  Train Epoch: 34 [0/46 (0%)]	Loss: 2.371227 Acc: 87.47%/87.47%
#  Train Epoch: 34 [16/46 (35%)]	Loss: 2.395638 Acc: 87.66%/87.43%
#  Train Epoch: 34 [32/46 (70%)]	Loss: 2.627386 Acc: 87.12%/87.29%
# Train set: Average loss: 2.4627 Acc:87.29%
# Test set: Average loss: 2.5634, Accuracy:(86.85%)
#  Train Epoch: 35 [0/46 (0%)]	Loss: 2.710111 Acc: 84.65%/84.65%
#  Train Epoch: 35 [16/46 (35%)]	Loss: 2.343461 Acc: 87.46%/87.55%
#  Train Epoch: 35 [32/46 (70%)]	Loss: 2.399336 Acc: 87.65%/87.33%
# Train set: Average loss: 2.4500 Acc:87.25%
# Test set: Average loss: 2.5463, Accuracy:(87.10%)
#  Train Epoch: 36 [0/46 (0%)]	Loss: 2.301261 Acc: 87.22%/87.22%
#  Train Epoch: 36 [16/46 (35%)]	Loss: 2.434385 Acc: 87.37%/87.14%
#  Train Epoch: 36 [32/46 (70%)]	Loss: 2.515034 Acc: 86.37%/87.13%
# Train set: Average loss: 2.4417 Acc:87.17%
# Test set: Average loss: 2.5142, Accuracy:(87.12%)
#  Train Epoch: 37 [0/46 (0%)]	Loss: 2.414332 Acc: 86.75%/86.75%
#  Train Epoch: 37 [16/46 (35%)]	Loss: 2.399543 Acc: 87.38%/87.08%
#  Train Epoch: 37 [32/46 (70%)]	Loss: 2.548237 Acc: 87.24%/87.37%
# Train set: Average loss: 2.4042 Acc:87.33%
# Test set: Average loss: 2.4940, Accuracy:(86.91%)
#  Train Epoch: 38 [0/46 (0%)]	Loss: 2.467994 Acc: 87.30%/87.30%
#  Train Epoch: 38 [16/46 (35%)]	Loss: 2.075397 Acc: 89.39%/87.76%
#  Train Epoch: 38 [32/46 (70%)]	Loss: 2.460591 Acc: 86.15%/87.66%
# Train set: Average loss: 2.3400 Acc:87.65%
# Test set: Average loss: 2.6294, Accuracy:(86.19%)
#  Train Epoch: 39 [0/46 (0%)]	Loss: 2.659768 Acc: 86.21%/86.21%
#  Train Epoch: 39 [16/46 (35%)]	Loss: 2.514606 Acc: 88.17%/87.53%
#  Train Epoch: 39 [32/46 (70%)]	Loss: 2.238910 Acc: 88.56%/87.59%
# Train set: Average loss: 2.3808 Acc:87.50%
# Test set: Average loss: 2.4631, Accuracy:(87.17%)
#  Train Epoch: 40 [0/46 (0%)]	Loss: 2.157221 Acc: 88.88%/88.88%
#  Train Epoch: 40 [16/46 (35%)]	Loss: 2.434103 Acc: 86.86%/87.98%
#  Train Epoch: 40 [32/46 (70%)]	Loss: 2.463306 Acc: 86.24%/87.84%
# Train set: Average loss: 2.2979 Acc:87.95%
# Test set: Average loss: 2.3717, Accuracy:(87.54%)
#  Train Epoch: 41 [0/46 (0%)]	Loss: 2.223135 Acc: 88.63%/88.63%
#  Train Epoch: 41 [16/46 (35%)]	Loss: 2.089212 Acc: 89.65%/87.70%
#  Train Epoch: 41 [32/46 (70%)]	Loss: 2.337976 Acc: 87.49%/87.53%
# Train set: Average loss: 2.3154 Acc:87.60%
# Test set: Average loss: 2.4096, Accuracy:(87.37%)
#  Train Epoch: 42 [0/46 (0%)]	Loss: 2.241414 Acc: 89.21%/89.21%
#  Train Epoch: 42 [16/46 (35%)]	Loss: 2.078186 Acc: 88.99%/88.32%
#  Train Epoch: 42 [32/46 (70%)]	Loss: 2.350371 Acc: 87.47%/88.09%
# Train set: Average loss: 2.2738 Acc:87.90%
# Test set: Average loss: 2.3575, Accuracy:(87.63%)
#  Train Epoch: 43 [0/46 (0%)]	Loss: 2.255384 Acc: 88.23%/88.23%
#  Train Epoch: 43 [16/46 (35%)]	Loss: 2.260723 Acc: 87.40%/87.55%
#  Train Epoch: 43 [32/46 (70%)]	Loss: 2.291341 Acc: 87.27%/87.50%
# Train set: Average loss: 2.3359 Acc:87.46%
# Test set: Average loss: 2.3581, Accuracy:(87.73%)
#  Train Epoch: 44 [0/46 (0%)]	Loss: 2.286768 Acc: 87.57%/87.57%
#  Train Epoch: 44 [16/46 (35%)]	Loss: 1.907941 Acc: 90.06%/87.58%
#  Train Epoch: 44 [32/46 (70%)]	Loss: 2.682530 Acc: 84.79%/87.62%
# Train set: Average loss: 2.2912 Acc:87.71%
# Test set: Average loss: 2.4279, Accuracy:(87.23%)
#  Train Epoch: 45 [0/46 (0%)]	Loss: 2.269009 Acc: 87.67%/87.67%
#  Train Epoch: 45 [16/46 (35%)]	Loss: 2.285744 Acc: 87.70%/87.88%
#  Train Epoch: 45 [32/46 (70%)]	Loss: 2.143649 Acc: 89.15%/88.04%
# Train set: Average loss: 2.2480 Acc:87.97%
# Test set: Average loss: 2.3427, Accuracy:(87.64%)
#  Train Epoch: 46 [0/46 (0%)]	Loss: 2.301819 Acc: 87.63%/87.63%
#  Train Epoch: 46 [16/46 (35%)]	Loss: 2.520958 Acc: 86.62%/87.94%
#  Train Epoch: 46 [32/46 (70%)]	Loss: 2.127724 Acc: 88.69%/87.95%
# Train set: Average loss: 2.2529 Acc:87.94%
# Test set: Average loss: 2.3887, Accuracy:(87.48%)
#  Train Epoch: 47 [0/46 (0%)]	Loss: 2.511446 Acc: 87.39%/87.39%
#  Train Epoch: 47 [16/46 (35%)]	Loss: 2.364687 Acc: 87.54%/87.89%
#  Train Epoch: 47 [32/46 (70%)]	Loss: 2.244820 Acc: 87.45%/87.94%
# Train set: Average loss: 2.2215 Acc:87.99%
# Test set: Average loss: 2.2657, Accuracy:(88.11%)
#  Train Epoch: 48 [0/46 (0%)]	Loss: 2.343066 Acc: 85.87%/85.87%
#  Train Epoch: 48 [16/46 (35%)]	Loss: 2.045731 Acc: 89.06%/87.71%
#  Train Epoch: 48 [32/46 (70%)]	Loss: 2.244142 Acc: 88.68%/87.76%
# Train set: Average loss: 2.2479 Acc:87.78%
# Test set: Average loss: 2.4366, Accuracy:(86.85%)
#  Train Epoch: 49 [0/46 (0%)]	Loss: 2.409180 Acc: 86.88%/86.88%
#  Train Epoch: 49 [16/46 (35%)]	Loss: 2.169194 Acc: 87.54%/87.49%
#  Train Epoch: 49 [32/46 (70%)]	Loss: 2.247493 Acc: 87.58%/87.63%
# Train set: Average loss: 2.2509 Acc:87.65%
# Test set: Average loss: 2.3474, Accuracy:(87.58%)

# %%
def train(epoch,model,train_data_loader,optimizer,scheduler,
          criterion=nn.MSELoss(),topk_num=2):
    model.train()
    train_loss = 0.
    accuracy=[]
    print_time=int(len(train_data_loader)/3)+1
    for batch_idx, (data, target,_,_) in enumerate(train_data_loader):
        data, target = data.float(), target.float()
#         target=torch.tensor(np.random.normal(loc=target.item(), scale=std.item(), size=1)).float()
    
#         target=target.view((-1,))
        if cuda:
            data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        represent,c_feature,encoded_data,loss,cpc_ac = model(data,target)
        train_loss+=loss.data.item()
        cpc_loss=loss.data.item()
        accuracy.append(cpc_ac.item())
        batch_size=represent.size()[0]
        inner_coding=represent.clone()
        represent=represent.reshape((batch_size,-1))
        represent=represent-represent.min(dim=0,keepdims=True)[0]
        represent=represent/(represent.abs().max(dim=0,keepdims=True)[0]+1e-4)
        r_loss=(represent.unsqueeze(1)-represent.unsqueeze(0)).abs().topk(topk_num*4,
                                                                          largest=True,dim=-1)[0].mean()
        inner_coding=F.softmax(inner_coding,dim=-2).permute(0,2,1)
        inner_coding=torch.minimum(inner_coding,torch.tensor(0.95).cuda())
        inner_coding=torch.maximum(inner_coding,torch.tensor(0.05).cuda())
        c_loss=F.kl_div(inner_coding.unsqueeze(1).repeat([1,batch_size,1,1]).log(),
                        inner_coding.unsqueeze(0).repeat([batch_size,1,1,1]),reduction='none')
        c_loss=c_loss.sum(dim=-1).max(dim=-1)[0]
        c_loss=c_loss.mean()
        loss=loss-r_loss-c_loss
        loss.backward()
        optimizer.step()
        scheduler.step()
        if batch_idx % print_time == 0:
            print('\r Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} rLoss: {:.6f} cLoss: {:.6f} Acc: {:.2f}%/{:.2f}%'.format(
                epoch, batch_idx, len(train_data_loader),
                100. * batch_idx / len(train_data_loader), cpc_loss,
                r_loss.data.item(),c_loss.data.item(),
                100. *cpc_ac.item(),100. * np.mean(accuracy)))
    train_loss=train_loss/len(train_data_loader)
    print('Train set: Average loss: {:.4f} Acc:{:.2f}%'.format(
        train_loss, 100.* np.mean(accuracy)))
    return train_loss,np.mean(accuracy)
def experiment(num_epoch=5,lr=0.001,resume=True):
    global train_loader,test_loader,model_path,model
    start_epoch = 0
    best_res = 1e9
    losscurve = []
    accurve = []
    resume_state = get_best_checkpoint(model_path) if resume else None
    optimizer = torch.optim.Adam([{'params': model.cpc_model.prompt},
                                  {'params': model.cpc_model.projection.parameters()},
                                  {'params': model.cpc_model.gAR.parameters(), 'lr': 1e-4},
                                  {'params': model.cpc_model.gEncoder.parameters(), 'lr': 1e-4},
                                  {'params': model.cpc_criterion.parameters(), 'lr': 1e-4}
                                 ],
                                 lr=lr, weight_decay=0.0005)
    if resume_state and os.path.isfile(resume_state):
        print("=> loading checkpoint '{}'".format(resume_state))
        checkpoint = torch.load(resume_state,map_location={'cuda:0':'cuda:8'})
        start_epoch = checkpoint['epoch']+1
        best_res = checkpoint['best_res']
        losscurve = checkpoint['losscurve']
        accurve = checkpoint['accurve']
        model.load_state_dict(checkpoint['state_dict'])
        if cuda:
            model.cuda()
        scheduler = checkpoint['scheduler']
        print("=> loaded checkpoint '{}' (epoch {})"
              .format(resume_state, checkpoint['epoch']))
    else:
        if cuda:
            model.cuda()
        scheduler = lr_scheduler.CyclicLR(optimizer, lr / 10, lr*2, step_size_up=10, step_size_down=10,
                                       cycle_momentum=False, mode="triangular")
    
    
    for epoch in range(start_epoch,start_epoch+num_epoch):
        is_best = False
        train_loss,train_ac = train(epoch,model,train_loader,optimizer,scheduler)
        _,_,_, val_loss,val_ac = test(model,valid_loader)
        losscurve.append((train_loss, val_loss))
        accurve.append((train_ac,val_ac))
        if cuda:
            model.cuda()
    return losscurve,accurve

# %%
model = union_model()
path_exist(model_path)
losscurve,accurve=experiment(20,lr=0.001,resume=True)
plt.plot([i[0] for i in losscurve],label="train loss")
plt.plot([i[1] for i in losscurve],label="validation loss")
plt.legend()
plt.show()
plt.plot([i[0] for i in accurve],label="train ac")
plt.plot([i[1] for i in accurve],label="validation ac")
plt.legend()
plt.show()
# Out:
# => loading checkpoint './model/cpc_open_har_mp//model_best.pth.tar'
# => loaded checkpoint './model/cpc_open_har_mp//model_best.pth.tar' (epoch 47)
#  Train Epoch: 48 [0/46 (0%)]	Loss: 2.399448 rLoss: 0.637021 cLoss: 0.242037 Acc: 86.77%/86.77%
#  Train Epoch: 48 [16/46 (35%)]	Loss: 2.178688 rLoss: 0.682323 cLoss: 1.239014 Acc: 88.14%/89.30%
#  Train Epoch: 48 [32/46 (70%)]	Loss: 2.159658 rLoss: 0.692415 cLoss: 1.873016 Acc: 87.71%/88.96%
# Train set: Average loss: 2.1201 Acc:88.76%
# Test set: Average loss: 2.2268, Accuracy:(88.17%)
#  Train Epoch: 49 [0/46 (0%)]	Loss: 2.204330 rLoss: 0.696333 cLoss: 2.160293 Acc: 88.43%/88.43%
#  Train Epoch: 49 [16/46 (35%)]	Loss: 2.221356 rLoss: 0.694169 cLoss: 2.281633 Acc: 87.92%/88.92%
#  Train Epoch: 49 [32/46 (70%)]	Loss: 2.019105 rLoss: 0.697914 cLoss: 2.348257 Acc: 89.43%/88.98%
# Train set: Average loss: 2.0891 Acc:88.95%
# Test set: Average loss: 2.2695, Accuracy:(88.14%)
#  Train Epoch: 50 [0/46 (0%)]	Loss: 2.163014 rLoss: 0.701868 cLoss: 2.379608 Acc: 89.20%/89.20%
#  Train Epoch: 50 [16/46 (35%)]	Loss: 2.168767 rLoss: 0.697931 cLoss: 2.411583 Acc: 89.49%/89.01%
#  Train Epoch: 50 [32/46 (70%)]	Loss: 2.261416 rLoss: 0.710974 cLoss: 2.433110 Acc: 88.90%/89.11%
# Train set: Average loss: 2.0984 Acc:89.03%
# Test set: Average loss: 2.2003, Accuracy:(88.55%)
#  Train Epoch: 51 [0/46 (0%)]	Loss: 2.026885 rLoss: 0.709510 cLoss: 2.443898 Acc: 89.58%/89.58%
#  Train Epoch: 51 [16/46 (35%)]	Loss: 2.092134 rLoss: 0.713387 cLoss: 2.483479 Acc: 90.30%/89.26%
#  Train Epoch: 51 [32/46 (70%)]	Loss: 1.959736 rLoss: 0.709430 cLoss: 2.474290 Acc: 89.41%/89.07%
# Train set: Average loss: 2.0694 Acc:89.14%
# Test set: Average loss: 2.1953, Accuracy:(88.95%)
#  Train Epoch: 52 [0/46 (0%)]	Loss: 2.270451 rLoss: 0.712142 cLoss: 2.493219 Acc: 87.93%/87.93%
#  Train Epoch: 52 [16/46 (35%)]	Loss: 2.085826 rLoss: 0.722147 cLoss: 2.489892 Acc: 88.78%/89.00%
#  Train Epoch: 52 [32/46 (70%)]	Loss: 2.075113 rLoss: 0.718277 cLoss: 2.503717 Acc: 88.95%/89.09%
# Train set: Average loss: 2.0733 Acc:89.12%
# Test set: Average loss: 2.1835, Accuracy:(88.64%)
#  Train Epoch: 53 [0/46 (0%)]	Loss: 2.130515 rLoss: 0.722211 cLoss: 2.497966 Acc: 87.32%/87.32%
#  Train Epoch: 53 [16/46 (35%)]	Loss: 2.147532 rLoss: 0.724278 cLoss: 2.510997 Acc: 88.63%/89.11%
#  Train Epoch: 53 [32/46 (70%)]	Loss: 2.000985 rLoss: 0.720893 cLoss: 2.511819 Acc: 88.80%/89.06%
# Train set: Average loss: 2.0701 Acc:89.02%
# Test set: Average loss: 2.1941, Accuracy:(88.54%)
#  Train Epoch: 54 [0/46 (0%)]	Loss: 1.845031 rLoss: 0.724016 cLoss: 2.531461 Acc: 89.92%/89.92%
#  Train Epoch: 54 [16/46 (35%)]	Loss: 2.092607 rLoss: 0.731554 cLoss: 2.531324 Acc: 88.37%/89.15%
#  Train Epoch: 54 [32/46 (70%)]	Loss: 2.054546 rLoss: 0.728235 cLoss: 2.525960 Acc: 89.39%/89.13%
# Train set: Average loss: 2.0447 Acc:89.13%
# Test set: Average loss: 2.1672, Accuracy:(88.89%)
#  Train Epoch: 55 [0/46 (0%)]	Loss: 2.035184 rLoss: 0.732196 cLoss: 2.525929 Acc: 89.30%/89.30%
#  Train Epoch: 55 [16/46 (35%)]	Loss: 1.973541 rLoss: 0.729296 cLoss: 2.540737 Acc: 89.84%/89.00%
#  Train Epoch: 55 [32/46 (70%)]	Loss: 2.090880 rLoss: 0.732010 cLoss: 2.542830 Acc: 89.56%/89.02%
# Train set: Average loss: 2.0646 Acc:89.02%
# Test set: Average loss: 2.1549, Accuracy:(88.87%)
#  Train Epoch: 56 [0/46 (0%)]	Loss: 2.070573 rLoss: 0.732044 cLoss: 2.537480 Acc: 88.91%/88.91%
#  Train Epoch: 56 [16/46 (35%)]	Loss: 2.001152 rLoss: 0.733695 cLoss: 2.543611 Acc: 89.43%/89.11%
#  Train Epoch: 56 [32/46 (70%)]	Loss: 2.079208 rLoss: 0.735994 cLoss: 2.538882 Acc: 88.42%/88.94%
# Train set: Average loss: 2.0348 Acc:89.08%
# Test set: Average loss: 2.1548, Accuracy:(88.89%)
#  Train Epoch: 57 [0/46 (0%)]	Loss: 2.023132 rLoss: 0.733978 cLoss: 2.549034 Acc: 89.34%/89.34%
#  Train Epoch: 57 [16/46 (35%)]	Loss: 1.981487 rLoss: 0.740723 cLoss: 2.541167 Acc: 90.73%/89.01%
#  Train Epoch: 57 [32/46 (70%)]	Loss: 1.978001 rLoss: 0.746008 cLoss: 2.552199 Acc: 89.28%/89.10%
# Train set: Average loss: 2.0499 Acc:89.18%
# Test set: Average loss: 2.1807, Accuracy:(88.62%)
#  Train Epoch: 58 [0/46 (0%)]	Loss: 1.997956 rLoss: 0.737803 cLoss: 2.556129 Acc: 90.26%/90.26%
#  Train Epoch: 58 [16/46 (35%)]	Loss: 1.812819 rLoss: 0.738744 cLoss: 2.552671 Acc: 90.76%/88.97%
#  Train Epoch: 58 [32/46 (70%)]	Loss: 2.258912 rLoss: 0.738315 cLoss: 2.539998 Acc: 88.00%/89.08%
# Train set: Average loss: 2.0652 Acc:89.00%
# Test set: Average loss: 2.2263, Accuracy:(88.24%)
#  Train Epoch: 59 [0/46 (0%)]	Loss: 1.865394 rLoss: 0.746156 cLoss: 2.563560 Acc: 90.73%/90.73%
#  Train Epoch: 59 [16/46 (35%)]	Loss: 2.093714 rLoss: 0.743473 cLoss: 2.561266 Acc: 88.69%/89.24%
#  Train Epoch: 59 [32/46 (70%)]	Loss: 2.189232 rLoss: 0.743401 cLoss: 2.547817 Acc: 87.74%/89.16%
# Train set: Average loss: 2.0601 Acc:89.04%
# Test set: Average loss: 2.1662, Accuracy:(88.75%)
#  Train Epoch: 60 [0/46 (0%)]	Loss: 2.114298 rLoss: 0.745715 cLoss: 2.565359 Acc: 88.39%/88.39%
#  Train Epoch: 60 [16/46 (35%)]	Loss: 2.172944 rLoss: 0.745554 cLoss: 2.558817 Acc: 88.11%/89.23%
#  Train Epoch: 60 [32/46 (70%)]	Loss: 1.983574 rLoss: 0.751767 cLoss: 2.564060 Acc: 89.52%/89.11%
# Train set: Average loss: 2.0282 Acc:89.18%
# Test set: Average loss: 2.2213, Accuracy:(88.07%)
#  Train Epoch: 61 [0/46 (0%)]	Loss: 1.916482 rLoss: 0.748993 cLoss: 2.561516 Acc: 90.19%/90.19%
#  Train Epoch: 61 [16/46 (35%)]	Loss: 2.188386 rLoss: 0.754209 cLoss: 2.562716 Acc: 87.99%/89.23%
#  Train Epoch: 61 [32/46 (70%)]	Loss: 1.992040 rLoss: 0.753588 cLoss: 2.561133 Acc: 89.37%/89.10%
# Train set: Average loss: 2.0478 Acc:89.07%
# Test set: Average loss: 2.2030, Accuracy:(88.65%)
#  Train Epoch: 62 [0/46 (0%)]	Loss: 2.121912 rLoss: 0.747434 cLoss: 2.566103 Acc: 88.50%/88.50%
#  Train Epoch: 62 [16/46 (35%)]	Loss: 2.045370 rLoss: 0.753745 cLoss: 2.558485 Acc: 89.03%/88.79%
#  Train Epoch: 62 [32/46 (70%)]	Loss: 2.055349 rLoss: 0.758514 cLoss: 2.567447 Acc: 88.82%/89.15%
# Train set: Average loss: 2.0488 Acc:89.12%
# Test set: Average loss: 2.1733, Accuracy:(88.62%)
#  Train Epoch: 63 [0/46 (0%)]	Loss: 2.100741 rLoss: 0.754564 cLoss: 2.557306 Acc: 88.72%/88.72%
#  Train Epoch: 63 [16/46 (35%)]	Loss: 1.988636 rLoss: 0.755882 cLoss: 2.566791 Acc: 89.77%/88.98%
#  Train Epoch: 63 [32/46 (70%)]	Loss: 1.938289 rLoss: 0.760740 cLoss: 2.565929 Acc: 89.57%/89.03%
# Train set: Average loss: 2.0600 Acc:88.99%
# Test set: Average loss: 2.1559, Accuracy:(88.48%)
#  Train Epoch: 64 [0/46 (0%)]	Loss: 1.813152 rLoss: 0.759248 cLoss: 2.567942 Acc: 89.54%/89.54%
#  Train Epoch: 64 [16/46 (35%)]	Loss: 2.062937 rLoss: 0.757625 cLoss: 2.564895 Acc: 89.26%/88.90%
#  Train Epoch: 64 [32/46 (70%)]	Loss: 1.719893 rLoss: 0.759388 cLoss: 2.562774 Acc: 91.03%/89.23%
# Train set: Average loss: 2.0195 Acc:89.13%
# Test set: Average loss: 2.1690, Accuracy:(88.53%)
#  Train Epoch: 65 [0/46 (0%)]	Loss: 2.073112 rLoss: 0.755041 cLoss: 2.566892 Acc: 88.15%/88.15%
#  Train Epoch: 65 [16/46 (35%)]	Loss: 2.160400 rLoss: 0.757315 cLoss: 2.572020 Acc: 88.12%/89.55%
#  Train Epoch: 65 [32/46 (70%)]	Loss: 1.896277 rLoss: 0.760149 cLoss: 2.565043 Acc: 89.77%/89.20%
# Train set: Average loss: 2.0259 Acc:89.14%
# Test set: Average loss: 2.1755, Accuracy:(88.60%)
#  Train Epoch: 66 [0/46 (0%)]	Loss: 2.323739 rLoss: 0.760197 cLoss: 2.560346 Acc: 87.36%/87.36%
#  Train Epoch: 66 [16/46 (35%)]	Loss: 1.783912 rLoss: 0.763917 cLoss: 2.572679 Acc: 90.49%/89.44%
#  Train Epoch: 66 [32/46 (70%)]	Loss: 2.114783 rLoss: 0.770557 cLoss: 2.570564 Acc: 89.03%/89.44%
# Train set: Average loss: 2.0171 Acc:89.33%
# Test set: Average loss: 2.1439, Accuracy:(88.80%)
#  Train Epoch: 67 [0/46 (0%)]	Loss: 2.215864 rLoss: 0.766313 cLoss: 2.572344 Acc: 87.66%/87.66%
#  Train Epoch: 67 [16/46 (35%)]	Loss: 1.978257 rLoss: 0.766652 cLoss: 2.580603 Acc: 90.26%/89.00%
#  Train Epoch: 67 [32/46 (70%)]	Loss: 2.107783 rLoss: 0.763653 cLoss: 2.570594 Acc: 89.06%/89.10%
# Train set: Average loss: 2.0269 Acc:89.10%
# Test set: Average loss: 2.0913, Accuracy:(89.06%)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report,confusion_matrix

def train_Dis(data_loader,epoch,pri=True,detail=False,edge_weight=None):
    model_Dis.train()
    sum_loss=0
    acc_counts=0
    counts=0
    for batch_idx, (data, target,_,_) in enumerate(data_loader):
        data=data.float()
        target=target.long()
        if cuda:
            data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        pred = model_Dis(data,target)
        loss = F.cross_entropy(pred, target)
        loss.backward()
        optimizer.step()
        scheduler.step()
        sum_loss+=loss.data.item()
        acc_counts+=pred.max(dim=-1)[1].eq(target).sum().data.item()
        counts+=len(target)
        # print(np.concatenate([pred.cpu().detach().numpy(),target.cpu().numpy()],axis=-1))
        # print(loss.data.item())
    if pri:
        print('Train Epoch: {}  mean Loss: {:.6f} mean ac: {:.6f}'.format(
                epoch, sum_loss/len(data_loader),acc_counts/counts))   
    return sum_loss/len(data_loader),acc_counts/counts
def test_Dis(data_loader,pri=True,detail=False,edge_weight=None,test=False):
    model_Dis.eval()
    test_loss=0.
    preds = []
    acc_counts=0
    counts=0
    test_score=[]
    conf_matrix_l=[]
    for batch_idx, (data, target,_,_) in enumerate(data_loader):
        data=data.float()
        target=target.long()
        if cuda:
            data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        pred = model_Dis(data,target)
        loss = F.cross_entropy(pred, target)
        test_loss+=loss.data.item()
        preds.append(pred.cpu().detach().numpy())
        acc_counts+=pred.max(dim=-1)[1].eq(target).sum().data.item()
        counts+=len(target)
        if detail:
            print(np.concatenate([pred.cpu().detach().numpy(),target.cpu().numpy()],axis=-1))
#             print(pred.cpu().detach().numpy())
#             print(target.cpu().numpy())
        if test:
            pred=pred.argmax(dim=-1).cpu().detach().numpy()
            sklearn_precision = precision_score(pred, target.cpu().numpy(), average='macro')
            sklearn_recall = recall_score(pred, target.cpu().numpy(), average='macro')
            sklearn_f1 = f1_score(pred, target.cpu().numpy(), average='macro')
            test_score.append([sklearn_precision,sklearn_recall,sklearn_f1])
            # print(classification_report(test_trues, test_preds))
            conf_matrix = confusion_matrix(pred, target.cpu().numpy(),labels=list(range(6)))
            conf_matrix_l.append(conf_matrix)
    test_loss /= len(data_loader)
    if pri:
        print('Test set: Average recon loss: {:.4f} mean ac: {:.6f}'.format(test_loss,acc_counts/counts))
    if test:
        print(np.mean(test_score,axis=0))
        # print(test_score)
        print(np.sum(conf_matrix_l,axis=0))
    return preds,test_loss,acc_counts/counts
def exp(epochs=50,pri=True,detail=False):
    train_loss_curve=[]
    val_loss_curve=[]
    test_loss_curve=[]
    train_acc_curve=[]
    val_acc_curve=[]
    test_acc_curve=[]
    bst_loss=1e-4
    for epoch in range(epochs):
        train_loss,train_acc=train_Dis(train_loader,epoch=epoch,pri=pri,detail=detail)
        _,val_loss,val_acc=test_Dis(valid_loader,pri=pri)
        _,test_loss,test_acc=test_Dis(test_loader,pri=pri)
        train_loss_curve.append(train_loss)
        val_loss_curve.append(val_loss)
        test_loss_curve.append(test_loss)
        train_acc_curve.append(train_acc)
        val_acc_curve.append(val_acc)
        test_acc_curve.append(test_acc)
        if val_acc>bst_loss:
            bst_loss=val_acc
            torch.save(model_Dis.state_dict(), model_path+"dis_model")
    model_Dis.load_state_dict(torch.load(model_path+"dis_model"))
    #only print once
    test_Dis(test_loader,pri=pri,test=True)
    return train_loss_curve,val_loss_curve,test_loss_curve,train_acc_curve,val_acc_curve,test_acc_curve,bst_loss

# %%
class dis_model(torch.nn.Module):
    def __init__(self,union_model,hidden=64,class_num=2):
        super(dis_model, self).__init__()
        self.cpc_model=union_model.cpc_model
        # self.final=nn.Linear(hidden*17,class_num)
        self.final=nn.Linear(hidden*4,class_num)
        for param in self.cpc_model.parameters():
            param.requires_grad = False
    def forward(self,x,label):
        batch=x.shape[0]
        represent,c_feature, encoded_data, label = self.cpc_model(x,label)
        represent=represent.reshape((batch,-1))
        x=represent
        x=self.final(x)
        return x

# %%
model_Dis=dis_model(model,64,6).cuda()
lr=1e-3
optimizer = torch.optim.Adam(model_Dis.final.parameters(), lr=lr, weight_decay=0.0005)
scheduler = lr_scheduler.CyclicLR(optimizer, lr / 10, lr*2, step_size_up=10, step_size_down=10,
                                       cycle_momentum=False, mode="triangular")
train_loss_curve,val_loss_curve,test_loss_curve,train_acc_curve,val_acc_curve,test_acc_curve,bst_loss=exp(40)
plt.figure(figsize=(12,8))
plt.plot(train_loss_curve,label="train loss")
plt.plot(val_loss_curve,label="validation loss")
plt.plot(test_loss_curve,label="test loss")
plt.legend()
plt.show()
plt.figure(figsize=(12,8))
plt.plot(train_acc_curve,label="train ac")
plt.plot(val_acc_curve,label="validation ac")
plt.plot(test_acc_curve,label="test ac")
plt.legend()
plt.show()
print(bst_loss)
# Out:
# Train Epoch: 0  mean Loss: 1.290370 mean ac: 0.510968
# Test set: Average recon loss: 0.8593 mean ac: 0.690687
# Test set: Average recon loss: 1.1791 mean ac: 0.571768
# Train Epoch: 1  mean Loss: 0.792831 mean ac: 0.717055
# Test set: Average recon loss: 0.6874 mean ac: 0.744392
# Test set: Average recon loss: 1.0382 mean ac: 0.647777
# Train Epoch: 2  mean Loss: 0.670273 mean ac: 0.763986
# Test set: Average recon loss: 0.5709 mean ac: 0.787220
# Test set: Average recon loss: 0.9823 mean ac: 0.674924
# Train Epoch: 3  mean Loss: 0.601064 mean ac: 0.792042
# Test set: Average recon loss: 0.5314 mean ac: 0.807614
# Test set: Average recon loss: 0.9236 mean ac: 0.705124
# Train Epoch: 4  mean Loss: 0.555598 mean ac: 0.806325
# Test set: Average recon loss: 0.4924 mean ac: 0.829368
# Test set: Average recon loss: 0.9230 mean ac: 0.705124
# Train Epoch: 5  mean Loss: 0.511196 mean ac: 0.826050
# Test set: Average recon loss: 0.4517 mean ac: 0.855880
# Test set: Average recon loss: 0.9058 mean ac: 0.723448
# Train Epoch: 6  mean Loss: 0.502599 mean ac: 0.828941
# Test set: Average recon loss: 0.4254 mean ac: 0.846363
# Test set: Average recon loss: 0.8658 mean ac: 0.725823
# Train Epoch: 7  mean Loss: 0.480852 mean ac: 0.833532
# Test set: Average recon loss: 0.4128 mean ac: 0.881713
# Test set: Average recon loss: 0.8506 mean ac: 0.733967
# Train Epoch: 8  mean Loss: 0.456834 mean ac: 0.841694
# Test set: Average recon loss: 0.3943 mean ac: 0.863358
# Test set: Average recon loss: 0.8529 mean ac: 0.719715
# Train Epoch: 9  mean Loss: 0.434425 mean ac: 0.849345
# Test set: Average recon loss: 0.3949 mean ac: 0.869477
# Test set: Average recon loss: 0.8673 mean ac: 0.749576
# Train Epoch: 10  mean Loss: 0.426225 mean ac: 0.846795
# Test set: Average recon loss: 0.3589 mean ac: 0.872196
# Test set: Average recon loss: 0.8050 mean ac: 0.736003
# Train Epoch: 11  mean Loss: 0.412036 mean ac: 0.856657
# Test set: Average recon loss: 0.3629 mean ac: 0.873555
# Test set: Average recon loss: 0.8233 mean ac: 0.733627
# Train Epoch: 12  mean Loss: 0.402158 mean ac: 0.853256
# Test set: Average recon loss: 0.3561 mean ac: 0.868797
# Test set: Average recon loss: 0.8068 mean ac: 0.738378
# Train Epoch: 13  mean Loss: 0.394501 mean ac: 0.858698
# Test set: Average recon loss: 0.3390 mean ac: 0.866077
# Test set: Average recon loss: 0.7726 mean ac: 0.744147
# Train Epoch: 14  mean Loss: 0.381699 mean ac: 0.861758
# Test set: Average recon loss: 0.3480 mean ac: 0.874915
# Test set: Average recon loss: 0.7684 mean ac: 0.739057
# Train Epoch: 15  mean Loss: 0.380654 mean ac: 0.856657
# Test set: Average recon loss: 0.3314 mean ac: 0.887152
# Test set: Average recon loss: 0.8047 mean ac: 0.739057
# Train Epoch: 16  mean Loss: 0.378765 mean ac: 0.860228
# Test set: Average recon loss: 0.3209 mean ac: 0.883073
# Test set: Average recon loss: 0.8275 mean ac: 0.769936
# Train Epoch: 17  mean Loss: 0.367224 mean ac: 0.868050
# Test set: Average recon loss: 0.3147 mean ac: 0.887152
# Test set: Average recon loss: 0.7949 mean ac: 0.751612
# Train Epoch: 18  mean Loss: 0.357401 mean ac: 0.870260
# Test set: Average recon loss: 0.3143 mean ac: 0.877634
# Test set: Average recon loss: 0.7460 mean ac: 0.757041
# Train Epoch: 19  mean Loss: 0.361314 mean ac: 0.858527
# Test set: Average recon loss: 0.3138 mean ac: 0.881033
# Test set: Average recon loss: 0.7243 mean ac: 0.753308
# Train Epoch: 20  mean Loss: 0.355115 mean ac: 0.863459
# Test set: Average recon loss: 0.2964 mean ac: 0.884432
# Test set: Average recon loss: 0.7555 mean ac: 0.760434
# Train Epoch: 21  mean Loss: 0.346981 mean ac: 0.870940
# Test set: Average recon loss: 0.2988 mean ac: 0.888511
# Test set: Average recon loss: 0.7302 mean ac: 0.755684
# Train Epoch: 22  mean Loss: 0.346302 mean ac: 0.866859
# Test set: Average recon loss: 0.2967 mean ac: 0.895989
# Test set: Average recon loss: 0.7894 mean ac: 0.743129
# Train Epoch: 23  mean Loss: 0.337210 mean ac: 0.872641
# Test set: Average recon loss: 0.2805 mean ac: 0.890551
# Test set: Average recon loss: 0.7749 mean ac: 0.763828
# Train Epoch: 24  mean Loss: 0.329815 mean ac: 0.872301
# Test set: Average recon loss: 0.2804 mean ac: 0.887831
# Test set: Average recon loss: 0.7537 mean ac: 0.756362
# Train Epoch: 25  mean Loss: 0.330228 mean ac: 0.873831
# Test set: Average recon loss: 0.2816 mean ac: 0.885792
# Test set: Average recon loss: 0.7252 mean ac: 0.759077
# Train Epoch: 26  mean Loss: 0.332192 mean ac: 0.868050
# Test set: Average recon loss: 0.2762 mean ac: 0.893950
# Test set: Average recon loss: 0.7389 mean ac: 0.758738
# Train Epoch: 27  mean Loss: 0.332720 mean ac: 0.870090
# Test set: Average recon loss: 0.2688 mean ac: 0.896669
# Test set: Average recon loss: 0.7464 mean ac: 0.762810
# Train Epoch: 28  mean Loss: 0.326450 mean ac: 0.879442
# Test set: Average recon loss: 0.2724 mean ac: 0.895989
# Test set: Average recon loss: 0.7649 mean ac: 0.752630
# Train Epoch: 29  mean Loss: 0.327352 mean ac: 0.872981
# Test set: Average recon loss: 0.2613 mean ac: 0.889871
# Test set: Average recon loss: 0.7653 mean ac: 0.760095
# Train Epoch: 30  mean Loss: 0.316599 mean ac: 0.877742
# Test set: Average recon loss: 0.2610 mean ac: 0.893950
# Test set: Average recon loss: 0.7407 mean ac: 0.762131
# Train Epoch: 31  mean Loss: 0.305198 mean ac: 0.878592
# Test set: Average recon loss: 0.2663 mean ac: 0.894630
# Test set: Average recon loss: 0.7433 mean ac: 0.774686
# Train Epoch: 32  mean Loss: 0.315920 mean ac: 0.878422
# Test set: Average recon loss: 0.2646 mean ac: 0.887152
# Test set: Average recon loss: 0.7352 mean ac: 0.764846
# Train Epoch: 33  mean Loss: 0.310044 mean ac: 0.878932
# Test set: Average recon loss: 0.2624 mean ac: 0.895989
# Test set: Average recon loss: 0.7496 mean ac: 0.754326
# Train Epoch: 34  mean Loss: 0.317253 mean ac: 0.877062
# Test set: Average recon loss: 0.2534 mean ac: 0.893950
# Test set: Average recon loss: 0.7442 mean ac: 0.763488
# Train Epoch: 35  mean Loss: 0.304039 mean ac: 0.878762
# Test set: Average recon loss: 0.2547 mean ac: 0.902107
# Test set: Average recon loss: 0.7658 mean ac: 0.758059
# Train Epoch: 36  mean Loss: 0.294429 mean ac: 0.885564
# Test set: Average recon loss: 0.2466 mean ac: 0.901428
# Test set: Average recon loss: 0.7534 mean ac: 0.762810
# Train Epoch: 37  mean Loss: 0.298113 mean ac: 0.884033
# Test set: Average recon loss: 0.2431 mean ac: 0.908226
# Test set: Average recon loss: 0.7774 mean ac: 0.764846
# Train Epoch: 38  mean Loss: 0.299346 mean ac: 0.884543
# Test set: Average recon loss: 0.2482 mean ac: 0.898708
# Test set: Average recon loss: 0.7493 mean ac: 0.752290
# Train Epoch: 39  mean Loss: 0.298631 mean ac: 0.883353
# Test set: Average recon loss: 0.2438 mean ac: 0.893950
# Test set: Average recon loss: 0.7502 mean ac: 0.779776
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/fzz/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test set: Average recon loss: 0.7774 mean ac: 0.764846
# [0.6912396  0.68843536 0.66017179]
# [[343 150  68   5   2   0]
#  [110 247  20   2   0   7]
#  [ 34   9 331   6   0   1]
#  [  9  23   0 370  67   0]
#  [  0   0   0  92 461  27]
#  [  0  42   1  16   2 502]]
# 0.9082256968048946
